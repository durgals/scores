# %% [markdown]
# # Test docstring

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
print("Python version")
print (sys.version)
#print("Version info.")
#print (sys.version_info)
# Out:
# Python version
# 3.10.11 | packaged by conda-forge | (main, May 10 2023, 18:58:44) [GCC 11.3.0]

# %%
import numpy as np
import pandas as pd
import xarray as xr
#import scoringrules
#from scores.probability import crps_for_ensemble
#import properscoring
sys.path.append('/datasets/work/lw-hydrofct/work/common/Software/python_verification/')
import vrf_scores
from IPython.display import Math, display
#import pymvscore

# %%
# Print docstring
print(vrf_scores.kge.__doc__)
# Out:
#     Calculate the Kling-Gupta Efficiency (KGE) between observed and simulated or forecast.
#
#     KGE is a performance metric that decomposes the error into three components:
#     correlation, bias, and variability.
#     It is computed as:
#
#     .. math::
#     \text{KGE} = 1 - \sqrt{(r - 1)^2 + (\alpha - 1)^2 + (\beta - 1)^2}
#
#     where:
#     - :math:`r` is the Pearson correlation coefficient between observed and simulated data:
#
#     .. math::
#       r = \frac{\text{cov}(Q_{\text{obs}}, Q_{\text{sim}})}{\sigma_{\text{obs}} \sigma_{\text{sim}}}
#
#     - :math:`\alpha` is the ratio of the standard deviations (variability ratio):
#
#     .. math::
#       \alpha = \frac{\sigma_{\text{sim}}}{\sigma_{\text{obs}}}
#
#     - :math:`\beta` is the ratio of the means (bias):
#
#     .. math::
#       \beta = \frac{\mu_{\text{sim}}}{\mu_{\text{obs}}}
#
#     where:
#     - :math:`Q_{\text{obs}}` and :math:`Q_{\text{sim}}` are the observed and simulated data, respectively.
# ...

# %%
# Display the KGE equation
display(Math(r"\text{KGE} = 1 - \sqrt{(\\rho - 1)^2 + (\alpha - 1)^2 + (\beta - 1)^2}"))
# Out:
# $\displaystyle \text{KGE} = 1 - \sqrt{(\\rho - 1)^2 + (\alpha - 1)^2 + (\beta - 1)^2}$

# %%
display(Math(r"\rho = \frac{\text{cov}(x, y)}{\sigma_x \sigma_y}"))
# Out:
# $\displaystyle \rho = \frac{\text{cov}(x, y)}{\sigma_x \sigma_y}$

# %%
display(Math(r"\alpha = \frac{\sigma_x}{\sigma_y}"))
# Out:
# $\displaystyle \alpha = \frac{\sigma_x}{\sigma_y}$

# %%
display(Math(r"\beta = \frac{\mu_x}{\mu_y}"))
# Out:
# $\displaystyle \beta = \frac{\mu_x}{\mu_y}$

# %%
display(Math(r"\\text{CRPS}(F, y) = \\int_{-\\infty}^{\\infty} \\left[F(x) - H(x - y)\\right]^2 \\, dF(x)"))
# Out:
# $\displaystyle \\text{CRPS}(F, y) = \\int_{-\\infty}^{\\infty} \\left[F(x) - H(x - y)\\right]^2 \\, dF(x)$
